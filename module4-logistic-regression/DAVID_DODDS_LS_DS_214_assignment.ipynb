# %% [markdown]
# <a href="https://colab.research.google.com/github/ddodds42/DS-Unit-2-Linear-Models/blob/master/module4-logistic-regression/DAVID_DODDS_LS_DS_214_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 4*
#
# ---

# %% [markdown]
# # Logistic Regression

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Linear-Models/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# Load data downloaded from https://srcole.github.io/100burritos/
import pandas as pd
df = pd.read_csv(DATA_PATH+'burritos/burritos.csv')

# %%
# Derive binary classification target:
# We define a 'Great' burrito as having an
# overall rating of 4 or higher, on a 5 point scale.
# Drop unrated burritos.
df = df.dropna(subset=['overall'])
df['Great'] = df['overall'] >= 4

# %%
# Clean/combine the Burrito categories
df['Burrito'] = df['Burrito'].str.lower()

california = df['Burrito'].str.contains('california')
asada = df['Burrito'].str.contains('asada')
surf = df['Burrito'].str.contains('surf')
carnitas = df['Burrito'].str.contains('carnitas')

df.loc[california, 'Burrito'] = 'California'
df.loc[asada, 'Burrito'] = 'Asada'
df.loc[surf, 'Burrito'] = 'Surf & Turf'
df.loc[carnitas, 'Burrito'] = 'Carnitas'
df.loc[~california & ~asada & ~surf & ~carnitas, 'Burrito'] = 'Other'

# %%
# Drop some high cardinality categoricals
df = df.drop(columns=['Notes', 'Location', 'Reviewer', 'Address', 'URL', 'Neighborhood'])

# %%
# Drop some columns to prevent "leakage"
df = df.drop(columns=['Rec', 'overall'])

# %%
df
# Out:
#         Burrito       Date  Yelp  Google  ... Avocado  Corn  Zucchini  Great
# 0    California  1/18/2016   3.5     4.2  ...     NaN   NaN       NaN  False
# 1    California  1/24/2016   3.5     3.3  ...     NaN   NaN       NaN  False
# 2      Carnitas  1/24/2016   NaN     NaN  ...     NaN   NaN       NaN  False
# 3         Asada  1/24/2016   NaN     NaN  ...     NaN   NaN       NaN  False
# 4    California  1/27/2016   4.0     3.8  ...     NaN   NaN       NaN   True
# ..          ...        ...   ...     ...  ...     ...   ...       ...    ...
# 418       Other  8/27/2019   NaN     NaN  ...     NaN   NaN       NaN  False
# 419       Other  8/27/2019   NaN     NaN  ...     NaN   NaN       NaN   True
# 420  California  8/27/2019   NaN     NaN  ...     NaN   NaN       NaN  False
# 421       Other  8/27/2019   NaN     NaN  ...     NaN   NaN       NaN   True
# 422       Other  8/27/2019   NaN     NaN  ...     NaN   NaN       NaN   True
#
# [421 rows x 59 columns]

# %%
df.isna().sum()
# Out:
# Burrito             0
# Date                0
# Yelp              334
# Google            334
# Chips             395
# Cost                7
# Hunger              3
# Mass (g)          399
# Density (g/mL)    399
# Length            138
# Circum            140
# Volume            140
# Tortilla            0
# Temp               20
# Meat               14
# Fillings            3
# Meat:filling        9
# Uniformity          2
# Salsa              25
# Synergy             2
# Wrap                3
# Unreliable        388
# NonSD             414
# Beef              242
# Pico              263
# Guac              267
# Cheese            262
# Fries             294
# Sour cream        329
# Pork              370
# Chicken           400
# Shrimp            400
# Fish              415
# Rice              385
# Beans             386
# Lettuce           410
# Tomato            414
# Bell peper        414
# Carrots           420
# Cabbage           413
# Sauce             383
# ...

# %%
for feature in list(df.columns):
  print(df[feature].value_counts())
  print('\n')
# Out:
# California     169
# Other          156
# Asada           43
# Surf & Turf     28
# Carnitas        25
# Name: Burrito, dtype: int64
#
#
# 8/30/2016    29
# 6/24/2016     9
# 8/27/2019     9
# 5/13/2016     7
# 4/15/2016     7
#              ..
# 8/10/2016     1
# 1/2/2018      1
# 3/19/2016     1
# 2/23/2017     1
# 5/28/2016     1
# Name: Date, Length: 169, dtype: int64
#
#
# 4.0    41
# 4.5    18
# 3.5    18
# 3.0     7
# 2.5     2
# 4.2     1
# Name: Yelp, dtype: int64
#
#
# 4.4    12
# 4.1    12
# 4.2    11
# 4.0     9
# 4.5     6
# 4.3     6
# 3.9     6
# 3.8     6
# 4.7     4
# 4.6     3
# 3.4     2
# 3.7     2
# 4.9     2
# 3.3     2
# 4.8     1
# 2.9     1
# 5.0     1
# 3.5     1
# Name: Google, dtype: int64
#
#
# x      21
# X       3
# No      1
# Yes     1
# Name: Chips, dtype: int64
#
#
# 6.25     40
# 5.99     23
# 6.99     23
# 7.90     20
# 7.50     17
#          ..
# 6.70      1
# 11.50     1
# 25.00     1
# 4.59      1
# 5.45      1
# ...

# %%
df0 = df.drop(columns='Queso')
'Queso' in list(df0.columns)
# Out:
# False

# %%
df0['Year'] = pd.DatetimeIndex(df['Date']).year
df0.head()
# Out:
#       Burrito       Date  Yelp  Google Chips  ...  Avocado  Corn  Zucchini  Great  Year
# 0  California  1/18/2016   3.5     4.2   NaN  ...      NaN   NaN       NaN  False  2016
# 1  California  1/24/2016   3.5     3.3   NaN  ...      NaN   NaN       NaN  False  2016
# 2    Carnitas  1/24/2016   NaN     NaN   NaN  ...      NaN   NaN       NaN  False  2016
# 3       Asada  1/24/2016   NaN     NaN   NaN  ...      NaN   NaN       NaN  False  2016
# 4  California  1/27/2016   4.0     3.8     x  ...      NaN   NaN       NaN   True  2016
#
# [5 rows x 59 columns]

# %%
df0['Month'] = pd.DatetimeIndex(df['Date']).month
df0.head()
# Out:
#       Burrito       Date  Yelp  Google Chips  ...  Corn  Zucchini  Great  Year  Month
# 0  California  1/18/2016   3.5     4.2   NaN  ...   NaN       NaN  False  2016      1
# 1  California  1/24/2016   3.5     3.3   NaN  ...   NaN       NaN  False  2016      1
# 2    Carnitas  1/24/2016   NaN     NaN   NaN  ...   NaN       NaN  False  2016      1
# 3       Asada  1/24/2016   NaN     NaN   NaN  ...   NaN       NaN  False  2016      1
# 4  California  1/27/2016   4.0     3.8     x  ...   NaN       NaN   True  2016      1
#
# [5 rows x 60 columns]

# %%
df0['Day'] = pd.DatetimeIndex(df['Date']).day
df0.head()
# Out:
#       Burrito       Date  Yelp  Google Chips  ...  Zucchini  Great  Year  Month  Day
# 0  California  1/18/2016   3.5     4.2   NaN  ...       NaN  False  2016      1   18
# 1  California  1/24/2016   3.5     3.3   NaN  ...       NaN  False  2016      1   24
# 2    Carnitas  1/24/2016   NaN     NaN   NaN  ...       NaN  False  2016      1   24
# 3       Asada  1/24/2016   NaN     NaN   NaN  ...       NaN  False  2016      1   24
# 4  California  1/27/2016   4.0     3.8     x  ...       NaN   True  2016      1   27
#
# [5 rows x 61 columns]

# %%
df1 = df0.drop(columns='Date')
'Date' in list(df1.columns)
# Out:
# False

# %%
df1['Chips'] = (
    df1['Chips']
    .str.replace('NaN','N')
    .str.replace('No','N')
    .str.replace('Yes','Y')
    .str.replace('X','Y')
    .str.replace('x','Y')
    # .astype(str)
)
df1.Chips.value_counts()
# Out:
# Y    25
# N     1
# Name: Chips, dtype: int64

# %%
df1.Chips.fillna(value='N', inplace=True)
df1.head()
# Out:
#       Burrito  Yelp  Google Chips  Cost  ...  Zucchini  Great  Year  Month  Day
# 0  California   3.5     4.2     N  6.49  ...       NaN  False  2016      1   18
# 1  California   3.5     3.3     N  5.45  ...       NaN  False  2016      1   24
# 2    Carnitas   NaN     NaN     N  4.85  ...       NaN  False  2016      1   24
# 3       Asada   NaN     NaN     N  5.25  ...       NaN  False  2016      1   24
# 4  California   4.0     3.8     Y  6.59  ...       NaN   True  2016      1   27
#
# [5 rows x 60 columns]

# %%
df1.loc[:,'Unreliable':'Zucchini'] = df1.loc[:,'Unreliable':'Zucchini'].replace('X', 'Y', regex=True).replace('x', 'Y', regex=True)
df1.head()
# Out:
#       Burrito  Yelp  Google Chips  Cost  ...  Zucchini  Great  Year  Month  Day
# 0  California   3.5     4.2     N  6.49  ...       NaN  False  2016      1   18
# 1  California   3.5     3.3     N  5.45  ...       NaN  False  2016      1   24
# 2    Carnitas   NaN     NaN     N  4.85  ...       NaN  False  2016      1   24
# 3       Asada   NaN     NaN     N  5.25  ...       NaN  False  2016      1   24
# 4  California   4.0     3.8     Y  6.59  ...       NaN   True  2016      1   27
#
# [5 rows x 60 columns]

# %%
df1.loc[:,'Unreliable':'Zucchini'] = df1.loc[:,'Unreliable':'Zucchini'].fillna(value='N')
df1.head()
# Out:
#       Burrito  Yelp  Google Chips  Cost  ...  Zucchini  Great  Year  Month  Day
# 0  California   3.5     4.2     N  6.49  ...         N  False  2016      1   18
# 1  California   3.5     3.3     N  5.45  ...         N  False  2016      1   24
# 2    Carnitas   NaN     NaN     N  4.85  ...         N  False  2016      1   24
# 3       Asada   NaN     NaN     N  5.25  ...         N  False  2016      1   24
# 4  California   4.0     3.8     Y  6.59  ...         N   True  2016      1   27
#
# [5 rows x 60 columns]

# %%
for feature in list(df1.columns):
  print(df1[feature].value_counts())
  print('\n')
# Out:
# California     169
# Other          156
# Asada           43
# Surf & Turf     28
# Carnitas        25
# Name: Burrito, dtype: int64
#
#
# 4.0    41
# 4.5    18
# 3.5    18
# 3.0     7
# 2.5     2
# 4.2     1
# Name: Yelp, dtype: int64
#
#
# 4.4    12
# 4.1    12
# 4.2    11
# 4.0     9
# 4.5     6
# 4.3     6
# 3.9     6
# 3.8     6
# 4.7     4
# 4.6     3
# 3.4     2
# 3.7     2
# 4.9     2
# 3.3     2
# 4.8     1
# 2.9     1
# 5.0     1
# 3.5     1
# Name: Google, dtype: int64
#
#
# N    396
# Y     25
# Name: Chips, dtype: int64
#
#
# 6.25     40
# 5.99     23
# 6.99     23
# 7.90     20
# 7.50     17
#          ..
# 6.70      1
# 11.50     1
# 25.00     1
# 4.59      1
# 5.45      1
# Name: Cost, Length: 98, dtype: int64
#
#
# 4.00    126
# 3.50     82
# 3.00     80
# 2.00     26
# 5.00     22
# 2.50     22
# 4.50     21
# 1.00      7
# 3.20      4
# 4.30      4
# 3.70      3
# 3.80      3
# 3.75      3
# 1.50      2
# 3.90      2
# 4.20      2
# 4.25      1
# 0.50      1
# ...

# %%
df1.dtypes
# Out:
# Burrito            object
# Yelp              float64
# Google            float64
# Chips              object
# Cost              float64
# Hunger            float64
# Mass (g)          float64
# Density (g/mL)    float64
# Length            float64
# Circum            float64
# Volume            float64
# Tortilla          float64
# Temp              float64
# Meat              float64
# Fillings          float64
# Meat:filling      float64
# Uniformity        float64
# Salsa             float64
# Synergy           float64
# Wrap              float64
# Unreliable         object
# NonSD              object
# Beef               object
# Pico               object
# Guac               object
# Cheese             object
# Fries              object
# Sour cream         object
# Pork               object
# Chicken            object
# Shrimp             object
# Fish               object
# Rice               object
# Beans              object
# Lettuce            object
# ...

# %%
import category_encoders as ce
encoder = ce.OneHotEncoder(use_cat_names=True)

# %%
df1_encoded = encoder.fit_transform(df1)

# %%
train = df1_encoded[df1_encoded.Year <= 2016]
val = df1_encoded[df1_encoded.Year == 2017]
test = df1_encoded[df1_encoded.Year >= 2018]
train.shape, val.shape, test.shape
# Out:
# ((298, 101), (85, 101), (38, 101))

# %% [markdown]
# # Train / Val / Test split! Begin BASELINE

# %%
target = 'Great'
y_train = train[target]
y_train.value_counts(normalize=True)
# Out:
# False    0.590604
# True     0.409396
# Name: Great, dtype: float64

# %%
majority_class = y_train.mode()[0]
majority_class
# Out:
# False

# %%
from sklearn.metrics import accuracy_score

# %%
y_val = val[target]
y_pred = [majority_class] * len(y_val)
accuracy_score(y_val, y_pred)
# Out:
# 0.5529411764705883

# %% [markdown]
# #BASELINE = 55.29%

# %%
y_test = test[target]
y_test.shape
# Out:
# (38,)

# %%
X_train = train.drop(columns=['Great','Mass (g)','Density (g/mL)'])
X_train.head()
# Out:
#    Burrito_California  Burrito_Carnitas  Burrito_Asada  ...  Year  Month  Day
# 0                   1                 0              0  ...  2016      1   18
# 1                   1                 0              0  ...  2016      1   24
# 2                   0                 1              0  ...  2016      1   24
# 3                   0                 0              1  ...  2016      1   24
# 4                   1                 0              0  ...  2016      1   27
#
# [5 rows x 98 columns]

# %%
X_val = val.drop(columns=['Great','Mass (g)','Density (g/mL)'])
X_test = test.drop(columns=['Great','Mass (g)','Density (g/mL)'])
X_test.shape,X_val.shape
# Out:
# ((38, 98), (85, 98))

# %%
X_train.isnull().sum()
# Out:
# Burrito_California     0
# Burrito_Carnitas       0
# Burrito_Asada          0
# Burrito_Other          0
# Burrito_Surf & Turf    0
#                       ..
# Zucchini_N             0
# Zucchini_Y             0
# Year                   0
# Month                  0
# Day                    0
# Length: 98, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
import numpy as np
imputer = SimpleImputer()

# %%
X_train_imp = imputer.fit_transform(X_train)
X_val_imp = imputer.transform(X_val)
X_test_imp = imputer.transform(X_test)
X_train_imp.shape, X_val_imp.shape, X_test_imp.shape
# Out:
# ((298, 98), (85, 98), (38, 98))

# %%
scaler = StandardScaler()
X_train_sca = scaler.fit_transform(X_train_imp)
X_val_sca = scaler.transform(X_val_imp)
X_test_sca = scaler.transform(X_test_imp)
X_train_sca.shape, X_val_sca.shape, X_test_sca.shape
# Out:
# ((298, 98), (85, 98), (38, 98))

# %%
X_train_imp_sca = pd.DataFrame(X_train_sca, columns=X_train.columns)
X_val_imp_sca = pd.DataFrame(X_val_sca, columns=X_train.columns)
X_test_imp_sca = pd.DataFrame(X_test_sca, columns=X_train.columns)
X_train_imp_sca.shape, X_val_imp_sca.shape, X_test_imp_sca.shape
# Out:
# ((298, 98), (85, 98), (38, 98))

# %%
model = LogisticRegressionCV(max_iter=1000)
model.fit(X_train_imp_sca, y_train)
print('Validation Accuracy', model.score(X_val_imp_sca, y_val))
# Out:
# Validation Accuracy 0.7764705882352941

# %%
print('Test Accuracy', model.score(X_test_imp_sca, y_test))
# Out:
# Test Accuracy 0.7894736842105263

# %%
# %matplotlib inline
coefficients = pd.Series(model.coef_[0], X_train_imp_sca.columns)
coefficients
# Out:
# Burrito_California     0.361657
# Burrito_Carnitas      -0.116917
# Burrito_Asada         -0.026826
# Burrito_Other         -0.427335
# Burrito_Surf & Turf    0.245071
# Yelp                   0.112057
# Google                -0.004721
# Chips_N                0.025324
# Chips_Y               -0.025324
# Cost                   0.379896
# Hunger                 0.264202
# Length                 0.074851
# Circum                 0.038277
# Volume                 0.103648
# Tortilla               0.554991
# Temp                   0.589185
# Meat                   1.312680
# Fillings               0.950102
# Meat:filling           0.981998
# Uniformity             0.193212
# Salsa                  0.137158
# Synergy                1.374443
# Wrap                   0.116026
# Unreliable_N          -0.112221
# Unreliable_Y           0.112221
# NonSD_N               -0.046816
# NonSD_Y                0.046816
# Beef_Y                -0.230955
# Beef_N                 0.230955
# ...

# %% [markdown]
# ## Assignment 🌯
#
# You'll use a [**dataset of 400+ burrito reviews**](https://srcole.github.io/100burritos/). How accurately can you predict whether a burrito is rated 'Great'?
#
# > We have developed a 10-dimensional system for rating the burritos in San Diego. ... Generate models for what makes a burrito great and investigate correlations in its dimensions.
#
# - [x] Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# - [x] Begin with baselines for classification.
# - [x] Use scikit-learn for logistic regression.
# - [x] Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# - [ ] Get your model's test accuracy. (One time, at the end.)
# - [ ] Commit your notebook to your fork of the GitHub repo.
#
#
# ## Stretch Goals
#
# - [ ] Add your own stretch goal(s) !
# - [ ] Make exploratory visualizations.
# - [ ] Do one-hot encoding.
# - [ ] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [ ] Get and plot your coefficients.
# - [ ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).
